# %% [markdown]
# https://microsoft.github.io/autogen/stable//index.html <br>
# https://github.com/microsoft/autogen

# %% [markdown]
# Add below to your requirements.txt.
#
# Don't use autogen/pyautogen
#
#
# autogen-agentchat<br>
# autogen-core<br>
# autogen-extension<br>
# asyncio<br>
