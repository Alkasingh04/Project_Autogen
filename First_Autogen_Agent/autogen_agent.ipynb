# %% [markdown]
# # Introduction to AgentChat API to First AutoAgent

# %%
from autogen_ext.models.openai import OpenAIChatCompletionClient

model_client = OpenAIChatCompletionClient(
    model="gpt-4o",
    api_key="OPEN_API_KEY"
)

print("Client created successfully")
# Out:
# Client created successfully

# %%
import sys
# !{sys.executable} -m pip install "autogen-ext[openai]"
# Out:
# /Users/alkasingh/Desktop/Project_Autogen/Project_Autogen/autogen_env/bin/python: No module named pip

# %%
import autogen_ext
print(autogen_ext.__file__)
# Out:
# /Users/alkasingh/Desktop/Project_Autogen/Project_Autogen/autogen_env/lib/python3.13/site-packages/autogen_ext/__init__.py

# %% [markdown]
# We will use the AgentChat API Tocreate a simple Assistant Agent and explore it's capabilities.

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")

# %%
model_client = OpenAIChatCompletionClient(model = 'gpt-4o', api_key=api_key)

# %% [markdown]
# # Creating Our First Assistant Agent

# %% [markdown]
# The AssistantAgent is a versatile agent for conversations, powered by AgentChat.m

# %%
assistant = AssistantAgent(name = "assistant", model_client = model_client)

# %% [markdown]
# # Testing the Assistant Agent

# %% [markdown]
# We will use a run method to send the task and get a response.

# %%
result = await assistant.run(task = "What is the capital of India")
print(result)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 result = await assistant.run(task = "What is the capital of India")
#       2 print(result)
#
# File ~/Desktop/Project_Autogen/Project_Autogen/autogen_env/lib/python3.13/site-packages/autogen_agentchat/agents/_base_chat_agent.py:149, in BaseChatAgent.run(self, task, cancellation_token, output_task_messages)
#     147         else:
#     148             raise ValueError(f"Invalid message type in sequence: {type(msg)}")
# --> 149 response = await self.on_messages(input_messages, cancellation_token)
#     150 if response.inner_messages is not None:
#     151     output_messages += response.inner_messages
#
# ...

# %%
print(result.messages)
print(result.messages[-1].content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(result.messages)
#       2 print(result.messages[-1].content)
#
# NameError: name 'result' is not defined
